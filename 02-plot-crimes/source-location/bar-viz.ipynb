# %%
# NOTE: This script is unsolved - some of the code has been removed
# and is to be completed in demonstration

# %%
# Add function for notebook plots
# %matplotlib notebook

# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches

# %%
# Define variables
csv_path = '../Resources/SF_Police_Department_Incidents_2018_clean.csv'
dist_table ="../Resources/SF_dist.csv"
summary_table = '../Resources/output.csv'

# %%
# Read in dist_table
dist_table = pd.read_csv(dist_table)
# Read in CSV, run query, specify columns
df = pd.read_csv(csv_path)
df.head()
# Out:
#    IncidntNum        Category                                  Descript  \
# 0   189014013    NON-CRIMINAL  STAY AWAY OR COURT ORDER, NON-DV RELATED
# 1   186095971  OTHER OFFENSES                    OBSCENE PHONE CALLS(S)
# 2   186084021           FRAUD              CREDIT CARD, THEFT BY USE OF
# 3   186072593    NON-CRIMINAL                             LOST PROPERTY
# 4   186063279   LARCENY/THEFT              GRAND THEFT FROM LOCKED AUTO
#
#   DayOfWeek        Date   Time  PdDistrict      Resolution  \
# 0    Monday  01/01/2018  22:37     TARAVAL  ARREST, BOOKED
# 1    Monday  01/01/2018  08:00  TENDERLOIN            NONE
# 2    Monday  01/01/2018  00:01    NORTHERN            NONE
# 3    Monday  01/01/2018  17:00     MISSION            NONE
# 4    Monday  01/01/2018  22:00    SOUTHERN            NONE
#
#                    Address           X          Y  \
# 0    3500 Block of 19TH AV -122.474829  37.723976
# 1     500 Block of EDDY ST -122.416711  37.783357
# 2    1200 Block of EDDY ST -122.428223  37.781896
# 3  2100 Block of MARKET ST -122.429789  37.766652
# 4   800 Block of BRYANT ST -122.403405  37.775421
#
#                                     Location            PdId
# 0  (37.723975823482135, -122.47482947577244)  18901401371024
# 1   (37.78335703909351, -122.41671073384802)  18609597119050
# 2   (37.78189594886033, -122.42822330317604)  18608402109320
# 3   (37.766652147476215, -122.4297889869883)  18607259371000
# 4     (37.775420706711, -122.40340479147905)  18606327906244

# %%
# Apply lambda function to the value_counts       
dfnew=df.groupby('PdDistrict')['Category'].apply(lambda x: x.value_counts().head(1))
dfnew.header= ['PdDistrict','Category','SUM']
dfnew.to_csv(summary_table,header=True, index_label=dfnew.header)
summary_table_new = pd.read_csv(summary_table)
summary_table_new.head()
# Out:
#   PdDistrict       Category   SUM  Category.1
# 0    BAYVIEW  LARCENY/THEFT   816         NaN
# 1    CENTRAL  LARCENY/THEFT  2170         NaN
# 2  INGLESIDE  LARCENY/THEFT   534         NaN
# 3    MISSION  LARCENY/THEFT  1698         NaN
# 4   NORTHERN  LARCENY/THEFT  2191         NaN

# %%
# Add code to drop column
summary_table_new.drop(columns=["Category.1"])
summary_table_new.head()
# Out:
#   PdDistrict       Category   SUM  Category.1
# 0    BAYVIEW  LARCENY/THEFT   816         NaN
# 1    CENTRAL  LARCENY/THEFT  2170         NaN
# 2  INGLESIDE  LARCENY/THEFT   534         NaN
# 3    MISSION  LARCENY/THEFT  1698         NaN
# 4   NORTHERN  LARCENY/THEFT  2191         NaN

# %%
# Merge crime and district data
dist_output = pd.merge(summary_table_new, dist_table, how="left", left_on="PdDistrict", right_on="district")
dist_output.head()
# Out:
#   PdDistrict       Category   SUM  Category.1   district  AREA_MI2
# 0    BAYVIEW  LARCENY/THEFT   816         NaN    BAYVIEW      7.22
# 1    CENTRAL  LARCENY/THEFT  2170         NaN    CENTRAL      2.01
# 2  INGLESIDE  LARCENY/THEFT   534         NaN  INGLESIDE      6.94
# 3    MISSION  LARCENY/THEFT  1698         NaN    MISSION      2.89
# 4   NORTHERN  LARCENY/THEFT  2191         NaN   NORTHERN      2.97

# %%
dist_output.to_csv('../Resources/dist_data.csv', encoding="utf-8", index=True,index_label=1)
dfnew= pd.read_csv("../Resources/dIst_data.csv")

# %%
val='Count_Norm'

dist_output.loc[:,'Count_Norm'] = val
dist_output.assign(val="")

dist_output[val]=dfnew["SUM"]/dfnew["AREA_MI2"]
dist_output.reset_index(drop=True)
dist_output.head()
dist_output.to_csv('../Resources/norm_data.csv',header=True,index_label=1)

# %%
df = pd.read_csv('../Resources/norm_data.csv')
df.head(10)
# Out:
#    1  PdDistrict       Category   SUM  Category.1    district  AREA_MI2  \
# 0  0     BAYVIEW  LARCENY/THEFT   816         NaN     BAYVIEW      7.22
# 1  1     CENTRAL  LARCENY/THEFT  2170         NaN     CENTRAL      2.01
# 2  2   INGLESIDE  LARCENY/THEFT   534         NaN   INGLESIDE      6.94
# 3  3     MISSION  LARCENY/THEFT  1698         NaN     MISSION      2.89
# 4  4    NORTHERN  LARCENY/THEFT  2191         NaN    NORTHERN      2.97
# 5  5        PARK  LARCENY/THEFT   575         NaN        PARK      3.04
# 6  6    RICHMOND  LARCENY/THEFT   826         NaN    RICHMOND      4.95
# 7  7    SOUTHERN  LARCENY/THEFT  2481         NaN    SOUTHERN      3.28
# 8  8     TARAVAL  LARCENY/THEFT   767         NaN     TARAVAL     10.21
# 9  9  TENDERLOIN   NON-CRIMINAL   371         NaN  TENDERLOIN      0.40
#
#     Count_Norm
# 0   113.019391
# 1  1079.601990
# 2    76.945245
# 3   587.543253
# 4   737.710438
# 5   189.144737
# 6   166.868687
# 7   756.402439
# 8    75.122429
# 9   927.500000

# %%
df['Color'] = pd.Series(pd.factorize(df['Category'])[0]).map(
    lambda x: sns.color_palette()[x])

# Use seaborn bar plot
sns.barplot(x='PdDistrict',y='Count_Norm', label='Category',data=df,palette=df['Color'])

# Specify patches for legend
cat1 = mpatches.Patch(color='#3778bf', label='LARCENY/THEFT')
cat2 = mpatches.Patch(color='#e1812c', label='NON-CRIMINAL')

plt.legend(handles=[cat1,cat2], loc=1)

# plot labels
xlabels=plt.xlabel('PdDistrict')
plt.ylabel('Incidents \n(Count per Square Mile)')
plt.title('SFPD Recorded Incidents\n Year 2018')

# Rotate x labels
plt.xticks(rotation=80)

# Modify size and border
plt.gcf().subplots_adjust(bottom=.8)
plt.rcParams['figure.figsize'] = [8,7]
plt.ylim(ymax=1200)
plt.tight_layout(pad=5, w_pad=1, h_pad=1.0)

# Output result to png
fname='../Resources/bar-viz.png'
plt.savefig(fname)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Lorem Ipsum
